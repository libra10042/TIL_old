# %%
from selenium import webdriver

# %%
# 웹드라이버 로딩
driver = webdriver.Chrome()

# %%
# 요청
driver.get('https://movie.daum.net/premovie/released')

# %%
# 영화 목록들을 가져온다.
li_list = driver.find_elements_by_css_selector('#mArticle > ul.list_movie.\#movie > li')
li_list
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="6d3f1b16-7ecc-4564-a3df-0d9a268c830e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="21387a64-ac88-40ec-ba7a-c77745f9ce37")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="5db73697-8811-497a-b1ba-db7f2d8bd06d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="e3f9219d-9f6c-4534-87a0-0fb728f1f2f6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="3cfce48e-ac9e-40fb-823a-056859225e54")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="ebbda57c-c466-4c84-aca5-d83129afff00")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="807aa949-508c-4c88-80eb-226b91259376")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="8af5ba8d-1cc8-497d-9bba-ed714c2ddac8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="8560124b-e5be-46b3-9960-953a92190d6e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="9f78b764-e97e-4a21-a196-a7a7d3a6a3b8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="7face3f6-cd1a-4143-9e05-e6339184ed08")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="542dcf17-3c66-4b74-8945-d4e47d196f25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="4b96c4fb-cc30-4063-9511-0e8d1256f4e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="09e9705f-8d01-4745-8be8-c615bc76e4db")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="685ae92c-58f1-4097-bb99-468cb98df99f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="c50a1f6b-086e-45d8-a8ac-7c4a7ad4cc6d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="c4b87dfc-5f39-41b7-b6b8-873dd6066c7c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="dae85094-6ef6-4e4b-b70d-174dabfdd997")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="b9addf6f-c35b-48ad-a7f4-99e864de1e63")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="26d7f90d1abc6f8b586e7bac9c29e192", element="d3eda2af-338d-400e-a4aa-dc4357bfb8a8")>]

# %%
# li 태그의 수 만큼 반복문을 돌린다.
data_dic = {
    'name' : [],
    'point' : [],
    'date' : [],
    'percent' : []
}

for li_tag in li_list :
    name_tag = li_tag.find_element_by_css_selector('div.wrap_movie > div > a')
    point_tag = li_tag.find_elements_by_css_selector('div.wrap_movie > span.info_grade > a > span.wrap_grade.grade_netizen > span.num_grade')
    date_tag = li_tag.find_element_by_css_selector('div.wrap_movie > span.info_state')
    
    print(name_tag.text)
    print(point_tag[0].text)
    print(point_tag[1].text)
    print(point_tag[2].text)
    print(date_tag.text.split())
    print('-------------------------------')
# Out:
# 남산의 부장들
# 08
# .
# 04
# ['20.01.22', '개봉', '・', '예매율', '55.41%']
# -------------------------------
# 히트맨
# 07
# .
# 01
# ['20.01.22', '개봉', '・', '예매율', '22.9%']
# -------------------------------
# 미스터 주: 사라진 VIP
# 06
# .
# 00
# ['20.01.22', '개봉', '・', '예매율', '6.13%']
# -------------------------------
# 스파이 지니어스
# 08
# .
# 09
# ['20.01.22', '개봉', '・', '예매율', '5.77%']
# -------------------------------
# 해치지않아
# 06
# .
# 06
# ['20.01.15', '개봉', '・', '예매율', '3.43%']
# -------------------------------
# 닥터 두리틀
# 06
# .
# 07
# ['20.01.08', '개봉', '・', '예매율', '1.46%']
# -------------------------------
# 나쁜 녀석들 : 포에버
# 06
# .
# 07
# ['20.01.15', '개봉', '・', '예매율', '0.92%']
# -------------------------------
# 타오르는 여인의 초상
# 08
# .
# 04
# ['20.01.16', '개봉', '・', '예매율', '0.8%']
# -------------------------------
# 오즈의 마법사: 요술구두와 말하는 책
# 02
# .
# 08
# ['20.01.22', '개봉', '・', '예매율', '0.42%']
# -------------------------------
# 백두산
# 06
# .
# 05
# ['19.12.19', '개봉', '・', '예매율', '0.36%']
# -------------------------------
# 겨울왕국 2
# 07
# .
# 04
# ['19.11.21', '개봉', '・', '예매율', '0.34%']
# -------------------------------
# 스타워즈: 라이즈 오브 스카이워커
# 06
# .
# 09
# ['20.01.08', '개봉', '・', '예매율', '0.26%']
# -------------------------------
# 하이큐!! 땅 VS 하늘
# 07
# .
# 02
# ['20.01.23', '개봉', '・', '예매율', '0.24%']
# -------------------------------
# 천문: 하늘에 묻는다
# 08
# .
# 03
# ['19.12.26', '개봉', '・', '예매율', '0.22%']
# -------------------------------
# 나이브스 아웃
# 08
# .
# 02
# ['19.12.04', '개봉', '・', '예매율', '0.14%']
# -------------------------------
# 신비아파트 극장판 하늘도깨비 대 요르문간드
# 07
# .
# 07
# ['19.12.19', '개봉', '・', '예매율', '0.14%']
# -------------------------------
# 포드 V 페라리
# 08
# .
# 06
# ['19.12.04', '개봉', '・', '예매율', '0.14%']
# -------------------------------
# 사마에게
# 09
# .
# 02
# ['20.01.23', '개봉', '・', '예매율', '0.14%']
# -------------------------------
# 파바로티
# 08
# .
# 08
# ['20.01.01', '개봉', '・', '예매율', '0.11%']
# -------------------------------
# 피아니스트의 전설
# 09
# .
# 01
# ['20.01.01', '개봉', '・', '예매율', '0.09%']
# -------------------------------
