# %%
pip install feedparser
# Out:
# Requirement already satisfied: feedparser in c:\anaconda\lib\site-packages (5.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import feedparser
import pandas
import os
import time

# %%
# 요청할 페이지의 주소
site = 'https://openapi.naver.com/v1/search/news.xml'
# 헤더 정보
client_Id = 'HCEMLBusbJrqI4Fv2tYf'
client_Secret = 'j6W3i_fYiA'
# 파라미터
query = '역삼역맛집'
start = 1
display = 10

# %%
header_dict = {
    'X-Naver-Client-Id' : client_Id,
    'X-Naver-Client-Secret' : client_Secret
}

param_dict = {
    'query' : query,
    'start' : 1,
    'display' : 10
}

# %%
time.sleep(1)

response = requests.get(site, headers=header_dict, params=param_dict)
feeds = feedparser.parse(response.text)

# feed 라는 이름으로 item 외의 것들이 들어가 있고
# entries라는 이름으로 item 태그들이 담겨 있는 리스트가
# 들어가 있다.
total = feeds['feed']['total']
start = feeds['feed']['start']
display = feeds['feed']['display']

print(f'total : {total}, start : {start}, display : {display}')

for item_tag in feeds['entries'] :
    print(item_tag)
    
    df1 = pandas.DataFrame([
            [
                item_tag['title'],
                item_tag['originallink'],
                item_tag['link'],
                item_tag['description'],
                item_tag['published']
            ]
        ])
        

        
print('수집완료')
# Out:
# total : 363, start : 1, display : 10
# {'title': '강남<b>역 맛집</b> ‘봉우화로’, 신년모임 장소 찾는다면 주목', 'title_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': '강남<b>역 맛집</b> ‘봉우화로’, 신년모임 장소 찾는다면 주목'}, 'originallink': 'http://www.ihalla.com/read.php3?aid=1579767611672848348', 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://www.ihalla.com/read.php3?aid=1579767611672848348'}], 'link': 'http://www.ihalla.com/read.php3?aid=1579767611672848348', 'summary': '수준 높은 음식과 차별화된 서비스만 제공하기 위해 노력할 것”이라고 전했다. 단체 예약 및 기타 자세한 사항은 서울 강남구 <b>역삼</b>동 강남<b>역 맛집</b> ‘봉우화로’로 문의하면 된다.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': '수준 높은 음식과 차별화된 서비스만 제공하기 위해 노력할 것”이라고 전했다. 단체 예약 및 기타 자세한 사항은 서울 강남구 <b>역삼</b>동 강남<b>역 맛집</b> ‘봉우화로’로 문의하면 된다.'}, 'published': 'Thu, 23 Jan 2020 17:22:00 +0900', 'published_parsed': time.struct_time(tm_year=2020, tm_mon=1, tm_mday=23, tm_hour=8, tm_min=22, tm_sec=0, tm_wday=3, tm_yday=23, tm_isdst=0)}
#                                        0  \
# 0  강남<b>역 맛집</b> ‘봉우화로’, 신년모임 장소 찾는다면 주목
#
#                                                    1  \
# 0  http://www.ihalla.com/read.php3?aid=1579767611...
#
#                                                    2  \
# 0  http://www.ihalla.com/read.php3?aid=1579767611...
#
#                                                    3  \
# 0  수준 높은 음식과 차별화된 서비스만 제공하기 위해 노력할 것”이라고 전했다. 단체 ...
#
#                                  4
# 0  Thu, 23 Jan 2020 17:22:00 +0900
# {'title': '[안병익의 식신 <b>맛집</b>] 씹을수록 고소한 마성의 풍미, 영원한 소주친구 곱창구...', 'title_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': '[안병익의 식신 <b>맛집</b>] 씹을수록 고소한 마성의 풍미, 영원한 소주친구 곱창구...'}, 'originallink': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1362476', 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1362476'}], 'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1362476', 'summary': '서울 곱창 <b>맛집</b>으로는 청담동 삼성원조양곱창, 수유 황주집, <b>역삼</b>동 선릉역 부산양곱창, 상도동 상도곱창, 대치동 대치골한우곱창, 교대 거북곱창, 신논현 영동시장 함지곱창전문, 을지로 양미옥, 시청 서대문 장호왕곱창...', 'summary_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': '서울 곱창 <b>맛집</b>으로는 청담동 삼성원조양곱창, 수유 황주집, <b>역삼</b>동 선릉역 부산양곱창, 상도동 상도곱창, 대치동 대치골한우곱창, 교대 거북곱창, 신논현 영동시장 함지곱창전문, 을지로 양미옥, 시청 서대문 장호왕곱창...'}, 'published': 'Sat, 18 Jan 2020 00:11:00 +0900', 'published_parsed': time.struct_time(tm_year=2020, tm_mon=1, tm_mday=17, tm_hour=15, tm_min=11, tm_sec=0, tm_wday=4, tm_yday=17, tm_isdst=0)}
#                                                    0  \
# 0  [안병익의 식신 <b>맛집</b>] 씹을수록 고소한 마성의 풍미, 영원한 소주친구 ...
#
#                                                    1  \
# 0  http://www.enewstoday.co.kr/news/articleView.h...
#
#                                                    2  \
# 0  http://www.enewstoday.co.kr/news/articleView.h...
#
#                                                    3  \
# 0  서울 곱창 <b>맛집</b>으로는 청담동 삼성원조양곱창, 수유 황주집, <b>역삼<...
#
#                                  4
# 0  Sat, 18 Jan 2020 00:11:00 +0900
# {'title': "강남<b>역 맛집</b> '봉우화로', 평범한 고기집은 그만! 특별한 삼겹살 메뉴가 있는 ...", 'title_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': "강남<b>역 맛집</b> '봉우화로', 평범한 고기집은 그만! 특별한 삼겹살 메뉴가 있는 ..."}, 'originallink': 'http://www.kgdm.co.kr/news/articleView.html?idxno=676561', 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://www.kgdm.co.kr/news/articleView.html?idxno=676561'}], 'link': 'http://www.kgdm.co.kr/news/articleView.html?idxno=676561', 'summary': "직장동료, 친구, 가족들과 함께 단체 모임을 가지는데도 불편함 없이 넉넉하다. 덕분에 회식장소, 모임장소로 좋다는 평이다. 단체 예약 및 기타 자세한 사항은 서울 강남구 <b>역삼</b>동 강남<b>역 맛집</b> '봉우화로'로 문의하면 된다.", 'summary_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': "직장동료, 친구, 가족들과 함께 단체 모임을 가지는데도 불편함 없이 넉넉하다. 덕분에 회식장소, 모임장소로 좋다는 평이다. 단체 예약 및 기타 자세한 사항은 서울 강남구 <b>역삼</b>동 강남<b>역 맛집</b> '봉우화로'로 문의하면 된다."}, 'published': 'Thu, 09 Jan 2020 18:02:00 +0900', 'published_parsed': time.struct_time(tm_year=2020, tm_mon=1, tm_mday=9, tm_hour=9, tm_min=2, tm_sec=0, tm_wday=3, tm_yday=9, tm_isdst=0)}
#                                                    0  \
# 0  강남<b>역 맛집</b> '봉우화로', 평범한 고기집은 그만! 특별한 삼겹살 메뉴가...
#
#                                                    1  \
# 0  http://www.kgdm.co.kr/news/articleView.html?id...
#
#                                                    2  \
# 0  http://www.kgdm.co.kr/news/articleView.html?id...
#
#                                                    3  \
# 0  직장동료, 친구, 가족들과 함께 단체 모임을 가지는데도 불편함 없이 넉넉하다. 덕분...
#
#                                  4
# 0  Thu, 09 Jan 2020 18:02:00 +0900
# {'title': "[<b>맛집</b>로드] 신년파티… '맛과 멋' 있는 최애 메뉴", 'title_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': "[<b>맛집</b>로드] 신년파티… '맛과 멋' 있는 최애 메뉴"}, 'originallink': 'http://moneys.mt.co.kr/news/mwView.php?no=2019121617138014401', 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=417&aid=0000489023'}], 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=417&aid=0000489023', 'summary': '강남의 대표적인 오피스 상권인 <b>역삼</b>동 인근은 강남권에서 가장 큰 규모를 자랑하는 강남 파이낸스센터와... ◆채근담 <b>역삼역</b>의 랜드마크인 강남 파이낸스 센터에는 음식의 맛과 멋, 그리고 건강한 몸과 정신을 통해...', 'summary_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': '강남의 대표적인 오피스 상권인 <b>역삼</b>동 인근은 강남권에서 가장 큰 규모를 자랑하는 강남 파이낸스센터와... ◆채근담 <b>역삼역</b>의 랜드마크인 강남 파이낸스 센터에는 음식의 맛과 멋, 그리고 건강한 몸과 정신을 통해...'}, 'published': 'Fri, 03 Jan 2020 06:49:00 +0900', 'published_parsed': time.struct_time(tm_year=2020, tm_mon=1, tm_mday=2, tm_hour=21, tm_min=49, tm_sec=0, tm_wday=3, tm_yday=2, tm_isdst=0)}
#                                      0  \
# 0  [<b>맛집</b>로드] 신년파티… '맛과 멋' 있는 최애 메뉴
#
#                                                    1  \
# 0  http://moneys.mt.co.kr/news/mwView.php?no=2019...
#
#                                                    2  \
# 0  https://news.naver.com/main/read.nhn?mode=LSD&...
#
#                                                    3  \
# 0  강남의 대표적인 오피스 상권인 <b>역삼</b>동 인근은 강남권에서 가장 큰 규모를...
#
#                                  4
# 0  Fri, 03 Jan 2020 06:49:00 +0900
# {'title': '[안병익의 식신 <b>맛집</b>] &quot;올해도 수고했어&quot; 청춘을 위로해주는 따뜻한 한 그릇,...', 'title_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': '[안병익의 식신 <b>맛집</b>] &quot;올해도 수고했어&quot; 청춘을 위로해주는 따뜻한 한 그릇,...'}, 'originallink': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1358425', 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1358425'}], 'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1358425', 'summary': '서울 국밥 <b>맛집</b>으로는 명동 하동관, 인사동 이문설렁탕, 시청 무교동북어국집, 용두동 어머니대성집, 마포... 부여집, <b>역삼역</b> 이도곰탕, 대치동 외고집설렁탕, 보라매 등나무집, 잠실 유원설렁탕, 신사역 영동설렁탕...', 'summary_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': '서울 국밥 <b>맛집</b>으로는 명동 하동관, 인사동 이문설렁탕, 시청 무교동북어국집, 용두동 어머니대성집, 마포... 부여집, <b>역삼역</b> 이도곰탕, 대치동 외고집설렁탕, 보라매 등나무집, 잠실 유원설렁탕, 신사역 영동설렁탕...'}, 'published': 'Sat, 28 Dec 2019 00:10:00 +0900', 'published_parsed': time.struct_time(tm_year=2019, tm_mon=12, tm_mday=27, tm_hour=15, tm_min=10, tm_sec=0, tm_wday=4, tm_yday=361, tm_isdst=0)}
#                                                    0  \
# 0  [안병익의 식신 <b>맛집</b>] &quot;올해도 수고했어&quot; 청춘을 위...
#
#                                                    1  \
# 0  http://www.enewstoday.co.kr/news/articleView.h...
#
#                                                    2  \
# 0  http://www.enewstoday.co.kr/news/articleView.h...
#
#                                                    3  \
# 0  서울 국밥 <b>맛집</b>으로는 명동 하동관, 인사동 이문설렁탕, 시청 무교동북어...
#
#                                  4
# 0  Sat, 28 Dec 2019 00:10:00 +0900
# {'title': '삼겹살 먹으며 송년회 하기 좋은 고기집.. 강남<b>역 맛집</b> ‘봉우화로’', 'title_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': '삼겹살 먹으며 송년회 하기 좋은 고기집.. 강남<b>역 맛집</b> ‘봉우화로’'}, 'originallink': 'http://siminilbo.co.kr/news/newsview.php?ncode=1065587944407999', 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://siminilbo.co.kr/news/newsview.php?ncode=1065587944407999'}], 'link': 'http://siminilbo.co.kr/news/newsview.php?ncode=1065587944407999', 'summary': '수준 높은 음식과 차별화된 서비스만 제공하기 위해 노력할 것”이라고 전했다. 단체 예약 및 기타 자세한 사항은 서울 강남구 <b>역삼</b>동 강남<b>역 맛집</b> ‘봉우화로’로 문의하면 된다.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': '수준 높은 음식과 차별화된 서비스만 제공하기 위해 노력할 것”이라고 전했다. 단체 예약 및 기타 자세한 사항은 서울 강남구 <b>역삼</b>동 강남<b>역 맛집</b> ‘봉우화로’로 문의하면 된다.'}, 'published': 'Fri, 27 Dec 2019 18:06:00 +0900', 'published_parsed': time.struct_time(tm_year=2019, tm_mon=12, tm_mday=27, tm_hour=9, tm_min=6, tm_sec=0, tm_wday=4, tm_yday=361, tm_isdst=0)}
#                                               0  \
# 0  삼겹살 먹으며 송년회 하기 좋은 고기집.. 강남<b>역 맛집</b> ‘봉우화로’
#
#                                                    1  \
# 0  http://siminilbo.co.kr/news/newsview.php?ncode...
#
#                                                    2  \
# 0  http://siminilbo.co.kr/news/newsview.php?ncode...
#
#                                                    3  \
# 0  수준 높은 음식과 차별화된 서비스만 제공하기 위해 노력할 것”이라고 전했다. 단체 ...
#
#                                  4
# 0  Fri, 27 Dec 2019 18:06:00 +0900
# {'title': "연말 송년회는 논현<b>역 맛집</b> '취영루' 강남역 신논현 회식장소, 모임장소로 인...", 'title_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': "연말 송년회는 논현<b>역 맛집</b> '취영루' 강남역 신논현 회식장소, 모임장소로 인..."}, 'originallink': 'http://www.gvalley.co.kr/news/articleView.html?idxno=569008', 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://www.gvalley.co.kr/news/articleView.html?idxno=569008'}], 'link': 'http://www.gvalley.co.kr/news/articleView.html?idxno=569008', 'summary': '강남역 <b>역삼역 맛집</b> 취영루 강남역 상견례로 유명한 명성에 걸맞게 400명이 동시에 식사를 할 수 있는 단체석을 마련한 것은 물론 연말 송년회, 연인, 가족끼리 즐길 수 있는 단독 룸까지 구비돼 가족모임, 데이트코스로...', 'summary_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': '강남역 <b>역삼역 맛집</b> 취영루 강남역 상견례로 유명한 명성에 걸맞게 400명이 동시에 식사를 할 수 있는 단체석을 마련한 것은 물론 연말 송년회, 연인, 가족끼리 즐길 수 있는 단독 룸까지 구비돼 가족모임, 데이트코스로...'}, 'published': 'Tue, 24 Dec 2019 12:00:00 +0900', 'published_parsed': time.struct_time(tm_year=2019, tm_mon=12, tm_mday=24, tm_hour=3, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=358, tm_isdst=0)}
#                                                    0  \
# 0  연말 송년회는 논현<b>역 맛집</b> '취영루' 강남역 신논현 회식장소, 모임장소...
#
#                                                    1  \
# 0  http://www.gvalley.co.kr/news/articleView.html...
#
#                                                    2  \
# 0  http://www.gvalley.co.kr/news/articleView.html...
#
#                                                    3  \
# 0  강남역 <b>역삼역 맛집</b> 취영루 강남역 상견례로 유명한 명성에 걸맞게 400...
#
#                                  4
# 0  Tue, 24 Dec 2019 12:00:00 +0900
# {'title': "강남<b>역 맛집</b> '봉우화로', 삼겹살 먹으며 연말모임 장소로 눈길", 'title_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': "강남<b>역 맛집</b> '봉우화로', 삼겹살 먹으며 연말모임 장소로 눈길"}, 'originallink': 'http://www.newsrep.co.kr/news/articleView.html?idxno=104731', 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://www.newsrep.co.kr/news/articleView.html?idxno=104731'}], 'link': 'http://www.newsrep.co.kr/news/articleView.html?idxno=104731', 'summary': "수준 높은 음식과 차별화된 서비스만 제공하기 위해 노력할 것&quot;이라고 전했다. 단체 예약 및 기타 자세한 사항은 서울 강남구 <b>역삼</b>동 강남<b>역 맛집</b> '봉우화로'로 문의하면 된다.", 'summary_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': "수준 높은 음식과 차별화된 서비스만 제공하기 위해 노력할 것&quot;이라고 전했다. 단체 예약 및 기타 자세한 사항은 서울 강남구 <b>역삼</b>동 강남<b>역 맛집</b> '봉우화로'로 문의하면 된다."}, 'published': 'Fri, 20 Dec 2019 18:02:00 +0900', 'published_parsed': time.struct_time(tm_year=2019, tm_mon=12, tm_mday=20, tm_hour=9, tm_min=2, tm_sec=0, tm_wday=4, tm_yday=354, tm_isdst=0)}
#                                            0  \
# 0  강남<b>역 맛집</b> '봉우화로', 삼겹살 먹으며 연말모임 장소로 눈길
#
#                                                    1  \
# 0  http://www.newsrep.co.kr/news/articleView.html...
#
#                                                    2  \
# 0  http://www.newsrep.co.kr/news/articleView.html...
#
#                                                    3  \
# 0  수준 높은 음식과 차별화된 서비스만 제공하기 위해 노력할 것&quot;이라고 전했다...
#
#                                  4
# 0  Fri, 20 Dec 2019 18:02:00 +0900
# {'title': "<b>역삼역</b> 해산물 <b>맛집</b> '제주양가네 해물한상', 따뜻한 국물 메뉴 선봬", 'title_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': "<b>역삼역</b> 해산물 <b>맛집</b> '제주양가네 해물한상', 따뜻한 국물 메뉴 선봬"}, 'originallink': 'http://www.e2news.com/news/articleView.html?idxno=217538', 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://www.e2news.com/news/articleView.html?idxno=217538'}], 'link': 'http://www.e2news.com/news/articleView.html?idxno=217538', 'summary': '또한 주변 상권과 각종 SNS 등에서 소개되며 <b>역삼역 맛집</b>과 LG아트센터 <b>맛집</b>으로 입소문을 타고 퍼지기 시작하면서 해산물 <b>맛집</b>으로 자리를 잡기 시작했다고 업체 측은 설명했다. 해물한상 브랜드 관계자는 &quot;해물한상의...', 'summary_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': '또한 주변 상권과 각종 SNS 등에서 소개되며 <b>역삼역 맛집</b>과 LG아트센터 <b>맛집</b>으로 입소문을 타고 퍼지기 시작하면서 해산물 <b>맛집</b>으로 자리를 잡기 시작했다고 업체 측은 설명했다. 해물한상 브랜드 관계자는 &quot;해물한상의...'}, 'published': 'Wed, 11 Dec 2019 14:42:00 +0900', 'published_parsed': time.struct_time(tm_year=2019, tm_mon=12, tm_mday=11, tm_hour=5, tm_min=42, tm_sec=0, tm_wday=2, tm_yday=345, tm_isdst=0)}
#                                                    0  \
# 0  <b>역삼역</b> 해산물 <b>맛집</b> '제주양가네 해물한상', 따뜻한 국물 ...
#
#                                                    1  \
# 0  http://www.e2news.com/news/articleView.html?id...
#
#                                                    2  \
# 0  http://www.e2news.com/news/articleView.html?id...
#
#                                                    3  \
# 0  또한 주변 상권과 각종 SNS 등에서 소개되며 <b>역삼역 맛집</b>과 LG아트센...
#
#                                  4
# 0  Wed, 11 Dec 2019 14:42:00 +0900
# {'title': "'김영철의 동네한바퀴' 강남 스낵카 식당 위치는? 된장비빔밥-오리탕-콩비지백...", 'title_detail': {'type': 'text/plain', 'language': None, 'base': '', 'value': "'김영철의 동네한바퀴' 강남 스낵카 식당 위치는? 된장비빔밥-오리탕-콩비지백..."}, 'originallink': 'http://www.topstarnews.net/news/articleView.html?idxno=705285', 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://www.topstarnews.net/news/articleView.html?idxno=705285'}], 'link': 'http://www.topstarnews.net/news/articleView.html?idxno=705285', 'summary': '갈비비지전골 <b>맛집</b> 등을 만나거나 방문 또는 체험했다. <b>역삼역</b> 근처 강남 르네상스 사거리 인근에 위치한 스낵카 식당은 폐차 직전의 버스를 개조해 만들어진 곳이다. 도로 옆 작은 공터에 자리해 기사식당 형태로...', 'summary_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': '갈비비지전골 <b>맛집</b> 등을 만나거나 방문 또는 체험했다. <b>역삼역</b> 근처 강남 르네상스 사거리 인근에 위치한 스낵카 식당은 폐차 직전의 버스를 개조해 만들어진 곳이다. 도로 옆 작은 공터에 자리해 기사식당 형태로...'}, 'published': 'Sat, 07 Dec 2019 19:17:00 +0900', 'published_parsed': time.struct_time(tm_year=2019, tm_mon=12, tm_mday=7, tm_hour=10, tm_min=17, tm_sec=0, tm_wday=5, tm_yday=341, tm_isdst=0)}
#                                                0  \
# 0  '김영철의 동네한바퀴' 강남 스낵카 식당 위치는? 된장비빔밥-오리탕-콩비지백...
#
#                                                    1  \
# 0  http://www.topstarnews.net/news/articleView.ht...
#
#                                                    2  \
# 0  http://www.topstarnews.net/news/articleView.ht...
#
#                                                    3  \
# 0  갈비비지전골 <b>맛집</b> 등을 만나거나 방문 또는 체험했다. <b>역삼역</b...
#
#                                  4
# 0  Sat, 07 Dec 2019 19:17:00 +0900
# 수집완료
